# %%
def toffoli3(a,b,c,an1,an2,trg):
    qc.ccx(a,b,an1)
    qc.ccx(c,an1,an2)
    qc.cx(an2,trg)
    qc.ccx(c,an1,an2)
    qc.ccx(a,b,an1)
    
def toffoli4(a,b,c,d,an1,an2,an3,trg):
    qc.ccx(a,b,an1)
    qc.ccx(c,an1,an2)
    qc.ccx(d,an2,an3)
    qc.cx(an3,trg)
    qc.ccx(d,an2,an3)
    qc.ccx(c,an1,an2)
    qc.ccx(a,b,an1)
    
def toffoli5(a,b,c,d,e,trg):
    qc.ccx(a,b,anc[0])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(d,anc[1],anc[2])
    qc.ccx(e,anc[2],anc[3])
    qc.cx(anc[3],trg)
    qc.ccx(e,anc[2],anc[3])
    qc.ccx(d,anc[1],anc[2])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(a,b,anc[0])
    
def toffoli6(a,b,c,d,e,f,trg):
    qc.ccx(a,b,anc[0])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(d,anc[1],anc[2])
    qc.ccx(e,anc[2],anc[3])
    qc.ccx(f,anc[3],anc[4])
    qc.cx(anc[4],trg)
    qc.ccx(f,anc[3],anc[4])
    qc.ccx(e,anc[2],anc[3])
    qc.ccx(d,anc[1],anc[2])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(a,b,anc[0])
    
def initialization1(qc):
    for i in range(n):
        qc.cx(key[i],nfsr[i])
            
    for i in range(ivlen):
        if(nonce[i] == 1):
            qc.x(lfsr[i])
            
    for i in range(ivlen, n):
        qc.x(lfsr[i])

def initialization2(qc):
    for i in range(2):
        for j in range(n):
            qc.ccx(lfsr[(46+j)%n],nfsr[(63+j)%n],ye[0])
            qc.ccx(lfsr[(3+j)%n],lfsr[(46+j)%n],ye[1])
            qc.cx(lfsr[(25+j)%n],ye[2])
            qc.cx(lfsr[(64+j)%n],ye[2])
            qc.cx(lfsr[(3+j)%n],ye[3])
            qc.cx(lfsr[(46+j)%n],ye[3])
            qc.cx(lfsr[(64+j)%n],ye[3])
            qc.ccx(ye[2],ye[0],lfsr[(0+j)%n])
            qc.ccx(ye[2],ye[1],lfsr[(0+j)%n])
            qc.ccx(ye[3],lfsr[(64+j)%n],lfsr[(0+j)%n])
            qc.x(ye[1])
            qc.cx(ye[1],lfsr[(0+j)%n])
            qc.cx(nfsr[(63+j)%n],lfsr[(0+j)%n])
            qc.x(ye[1])
            qc.cx(lfsr[(64+j)%n],ye[3])
            qc.cx(lfsr[(46+j)%n],ye[3])
            qc.cx(lfsr[(3+j)%n],ye[3])
            qc.cx(lfsr[(64+j)%n],ye[2])
            qc.cx(lfsr[(25+j)%n],ye[2])
            qc.ccx(lfsr[(3+j)%n],lfsr[(46+j)%n],ye[1])
            qc.ccx(lfsr[(46+j)%n],nfsr[(63+j)%n],ye[0])
            qc.cx(nfsr[(1+j)%n],lfsr[0+j])
            qc.cx(nfsr[(2+j)%n],lfsr[0+j])
            qc.cx(nfsr[(4+j)%n],lfsr[0+j])
            qc.cx(nfsr[(10+j)%n],lfsr[0+j])
            qc.cx(nfsr[(31+j)%n],lfsr[0+j])
            qc.cx(nfsr[(43+j)%n],lfsr[0+j])
            qc.cx(nfsr[(56+j)%n],lfsr[0+j])
            
            
            qc.cx(lfsr[(0+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(9+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(14+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(21+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(28+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(33+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(37+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(45+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(52+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(60+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(62+j)%n],nfsr[(0+j)%n])
            qc.ccx(nfsr[(63+j)%n],nfsr[(60+j)%n],nfsr[(0+j)%n])
            qc.ccx(nfsr[(37+j)%n],nfsr[(33+j)%n],nfsr[(0+j)%n])
            qc.ccx(nfsr[(15+j)%n],nfsr[(9+j)%n],nfsr[(0+j)%n])
            toffoli3(nfsr[(60+j)%n],nfsr[(52+j)%n],nfsr[(45+j)%n],ge0[0],ge0[1],nfsr[(0+j)%n])
            toffoli3(nfsr[(33+j)%n],nfsr[(28+j)%n],nfsr[(21+j)%n],ge1[0],ge1[1],nfsr[(0+j)%n])
            toffoli4(nfsr[(63+j)%n],nfsr[(45+j)%n],nfsr[(28+j)%n],nfsr[(9+j)%n],ge2[0],ge2[1],ge2[2],nfsr[(0+j)%n])
            toffoli4(nfsr[(60+j)%n],nfsr[(52+j)%n],nfsr[(37+j)%n],nfsr[(33+j)%n],ge2[0],ge2[1],ge2[2],nfsr[(0+j)%n])
            toffoli4(nfsr[(63+j)%n],nfsr[(60+j)%n],nfsr[(21+j)%n],nfsr[(15+j)%n],ge2[0],ge2[1],ge2[2],nfsr[(0+j)%n])
            toffoli5(nfsr[(63+j)%n], nfsr[(60+j)%n],nfsr[(52+j)%n],nfsr[(45+j)%n],nfsr[(37+j)%n],nfsr[(0+j)%n])
            toffoli5(nfsr[(33+j)%n], nfsr[(28+j)%n],nfsr[(21+j)%n],nfsr[(15+j)%n],nfsr[(9+j)%n],nfsr[(0+j)%n])
            toffoli6(nfsr[(52+j)%n], nfsr[(45+j)%n],nfsr[(37+j)%n],nfsr[(33+j)%n],nfsr[(28+j)%n],nfsr[(21+j)%n],nfsr[(0+j)%n])
        
            qc.cx(lfsr[(13+j)%n],lfsr[(0+j)%n])
            qc.cx(lfsr[(23+j)%n],lfsr[(0+j)%n])
            qc.cx(lfsr[(38+j)%n],lfsr[(0+j)%n])
            qc.cx(lfsr[(51+j)%n],lfsr[(0+j)%n])
            qc.cx(lfsr[(62+j)%n],lfsr[(0+j)%n])
            
def keystream(qc):
        for j in range(kslen):
            qc.ccx(lfsr[(46+j)%n],nfsr[(63+j)%n],ye[0])
            qc.ccx(lfsr[(3+j)%n],lfsr[(46+j)%n],ye[1])
            qc.cx(lfsr[(25+j)%n],ye[2])
            qc.cx(lfsr[(64+j)%n],ye[2])
            qc.cx(lfsr[(3+j)%n],ye[3])
            qc.cx(lfsr[(46+j)%n],ye[3])
            qc.cx(lfsr[(64+j)%n],ye[3])
            qc.ccx(ye[2],ye[0],lfsr[(0+j)%n])
            qc.ccx(ye[2],ye[1],lfsr[(0+j)%n])
            qc.ccx(ye[3],lfsr[(64+j)%n],lfsr[(0+j)%n])
            qc.x(ye[1])
            qc.cx(ye[1],y[j])
            qc.cx(nfsr[(63+j)%n],y[j])
            qc.x(ye[1])
            qc.cx(lfsr[(64+j)%n],ye[3])
            qc.cx(lfsr[(46+j)%n],ye[3])
            qc.cx(lfsr[(3+j)%n],ye[3])
            qc.cx(lfsr[(64+j)%n],ye[2])
            qc.cx(lfsr[(25+j)%n],ye[2])
            qc.ccx(lfsr[(3+j)%n],lfsr[(46+j)%n],ye[1])
            qc.ccx(lfsr[(46+j)%n],nfsr[(63+j)%n],ye[0])
            
            
            qc.cx(nfsr[(1+j)%n],y[j])
            qc.cx(nfsr[(2+j)%n],y[j])
            qc.cx(nfsr[(4+j)%n],y[j])
            qc.cx(nfsr[(10+j)%n],y[j])
            qc.cx(nfsr[(31+j)%n],y[j])
            qc.cx(nfsr[(43+j)%n],y[j])
            qc.cx(nfsr[(56+j)%n],y[j])
            
            
            qc.cx(lfsr[(0+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(9+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(14+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(21+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(28+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(33+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(37+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(45+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(52+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(60+j)%n],nfsr[(0+j)%n])
            qc.cx(nfsr[(62+j)%n],nfsr[(0+j)%n])
            qc.ccx(nfsr[(63+j)%n],nfsr[(60+j)%n],nfsr[(0+j)%n])
            qc.ccx(nfsr[(37+j)%n],nfsr[(33+j)%n],nfsr[(0+j)%n])
            qc.ccx(nfsr[(15+j)%n],nfsr[(9+j)%n],nfsr[(0+j)%n])
            toffoli3(nfsr[(60+j)%n],nfsr[(52+j)%n],nfsr[(45+j)%n],ge0[0],ge0[1],nfsr[(0+j)%n])
            toffoli3(nfsr[(33+j)%n],nfsr[(28+j)%n],nfsr[(21+j)%n],ge1[0],ge1[1],nfsr[(0+j)%n])
            toffoli4(nfsr[(63+j)%n],nfsr[(45+j)%n],nfsr[(28+j)%n],nfsr[(9+j)%n],ge2[0],ge2[1],ge2[2],nfsr[(0+j)%n])
            toffoli4(nfsr[(60+j)%n],nfsr[(52+j)%n],nfsr[(37+j)%n],nfsr[(33+j)%n],ge2[0],ge2[1],ge2[2],nfsr[(0+j)%n])
            toffoli4(nfsr[(63+j)%n],nfsr[(60+j)%n],nfsr[(21+j)%n],nfsr[(15+j)%n],ge2[0],ge2[1],ge2[2],nfsr[(0+j)%n])
            toffoli5(nfsr[(63+j)%n], nfsr[(60+j)%n],nfsr[(52+j)%n],nfsr[(45+j)%n],nfsr[(37+j)%n],nfsr[(0+j)%n])
            toffoli5(nfsr[(33+j)%n], nfsr[(28+j)%n],nfsr[(21+j)%n],nfsr[(15+j)%n],nfsr[(9+j)%n],nfsr[(0+j)%n])
            toffoli6(nfsr[(52+j)%n], nfsr[(45+j)%n],nfsr[(37+j)%n],nfsr[(33+j)%n],nfsr[(28+j)%n],nfsr[(21+j)%n],nfsr[(0+j)%n])
        
            qc.cx(lfsr[(13+j)%n],lfsr[(0+j)%n])
            qc.cx(lfsr[(23+j)%n],lfsr[(0+j)%n])
            qc.cx(lfsr[(38+j)%n],lfsr[(0+j)%n])
            qc.cx(lfsr[(51+j)%n],lfsr[(0+j)%n])
            qc.cx(lfsr[(62+j)%n],lfsr[(0+j)%n])
            
            
from qiskit import *
# %matplotlib inline
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute

n = 80
clock = 160
ivlen = 64
kslen = 90

lfsr = QuantumRegister(n,name='l')
nfsr = QuantumRegister(n,name='n')
key = QuantumRegister(n,name='k')

ge0 = QuantumRegister(2, name = 'ge0')
ge1 = QuantumRegister(2, name = 'ge1')
ge2 = QuantumRegister(3, name = 'ge2')

y = QuantumRegister(kslen,name='y')
ye = QuantumRegister(4,name  = 'ye')
anc = QuantumRegister(5,name  = 'anc')

qc = QuantumCircuit(lfsr,nfsr,y,key,ye,ge0,ge1,ge2,anc)

nonce = [1]*64

 
initialization1(qc)
initialization2(qc)
keystream(qc)
