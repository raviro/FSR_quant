# %%
def toffoli3(a,b,c,trg):
    qc.ccx(a,b,anc[0])
    qc.ccx(c,anc[0],anc[1])
    qc.cx(anc[1],trg)
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(a,b,anc[0])
    
def toffoli4(a,b,c,d,trg):
    qc.ccx(a,b,anc[0])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(d,anc[1],anc[2])
    qc.cx(anc[2],trg)
    qc.ccx(d,anc[1],anc[2])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(a,b,anc[0])
    
def toffoli5(a,b,c,d,e,trg):
    qc.ccx(a,b,anc[0])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(d,anc[1],anc[2])
    qc.ccx(e,anc[2],anc[3])
    qc.cx(anc[3],trg)
    qc.ccx(e,anc[2],anc[3])
    qc.ccx(d,anc[1],anc[2])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(a,b,anc[0])
    
def toffoli6(a,b,c,d,e,f,trg):
    qc.ccx(a,b,anc[0])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(d,anc[1],anc[2])
    qc.ccx(e,anc[2],anc[3])
    qc.ccx(f,anc[3],anc[4])
    qc.cx(anc[4],trg)
    qc.ccx(f,anc[3],anc[4])
    qc.ccx(e,anc[2],anc[3])
    qc.ccx(d,anc[1],anc[2])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(a,b,anc[0])
    
def toffoli7(a,b,c,d,e,f,g,trg):
    qc.ccx(a,b,anc[0])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(d,anc[1],anc[2])
    qc.ccx(e,anc[2],anc[3])
    qc.ccx(f,anc[3],anc[4])
    qc.ccx(g,anc[4],anc[5])
    qc.cx(anc[5],trg)
    qc.ccx(g,anc[4],anc[5])
    qc.ccx(f,anc[3],anc[4])
    qc.ccx(e,anc[2],anc[3])
    qc.ccx(d,anc[1],anc[2])
    qc.ccx(c,anc[0],anc[1])
    qc.ccx(a,b,anc[0])
    

def phase1():
    for i in range(64):
        if(iv[i]==1):
            qc.x(nfsr2[i])
        qc.cx(key[i],nfsr2[i])
        
    for i in range(64,90):
        qc.cx(key[i],nfsr2[i])
        
    for i in range(29):
        qc.cx(key[i+90],nfsr1[i])
        
    qc.cx(key[119],nfsr1[29])
    qc.x(nfsr1[29])
    
    qc.x(nfsr1[30])
    
       
def phase2():
    for i in range(128):
        
        qc.cx(nfsr2[(7+i)%90], nfsr1[(0+i)%31])
        qc.cx(nfsr2[(11+i)%90], nfsr1[(0+i)%31])
        qc.cx(nfsr2[(30+i)%90], nfsr1[(0+i)%31])
        qc.cx(nfsr2[(40+i)%90], nfsr1[(0+i)%31])
        qc.cx(nfsr2[(45+i)%90], nfsr1[(0+i)%31])
        qc.cx(nfsr2[(54+i)%90], nfsr1[(0+i)%31])
        qc.cx(nfsr2[(71+i)%90], nfsr1[(0+i)%31])
        qc.cx(nfsr2[(5+i)%90], nfsr1[(0+i)%31])
        
        qc.ccx(nfsr2[(4+i)%90], nfsr2[(21+i)%90], nfsr1[(0+i)%31])
        qc.ccx(nfsr2[(9+i)%90], nfsr2[(52+i)%90], nfsr1[(0+i)%31])
        qc.ccx(nfsr2[(18+i)%90], nfsr2[(37+i)%90], nfsr1[(0+i)%31])
        qc.ccx(nfsr2[(44+i)%90], nfsr2[(76+i)%90], nfsr1[(0+i)%31])
        qc.ccx(nfsr2[(8+i)%90], nfsr2[(82+i)%90], nfsr1[(0+i)%31])
        
        toffoli3(nfsr2[(34+i)%90], nfsr2[(67+i)%90],nfsr2[(73+i)%90], nfsr1[(0+i)%31])
        toffoli4(nfsr2[(2+i)%90], nfsr2[(28+i)%90],nfsr2[(41+i)%90],nfsr2[(65+i)%90], nfsr1[(0+i)%31])
        
        toffoli5(nfsr2[(13+i)%90], nfsr2[(29+i)%90],nfsr2[(50+i)%90],nfsr2[(64+i)%90],nfsr2[(75+i)%90], nfsr1[(0+i)%31])
        toffoli6(nfsr2[(6+i)%90], nfsr2[(14+i)%90],nfsr2[(26+i)%90],nfsr2[(32+i)%90],nfsr2[(47+i)%90],nfsr2[(61+i)%90], nfsr1[(0+i)%31])
        toffoli7(nfsr2[(1+i)%90], nfsr2[(19+i)%90],nfsr2[(27+i)%90],nfsr2[(43+i)%90],nfsr2[(57+i)%90],nfsr2[(66+i)%90],nfsr2[(78+i)%90], nfsr1[(0+i)%31])
        
        qc.cx(nfsr1[(23+i)%31], nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(3+i)%31], nfsr1[(16+i)%31], nfsr1[(0+i)%31])
        toffoli3(nfsr1[(9+i)%31], nfsr1[(13+i)%31],nfsr1[(48+i)%31], nfsr1[(0+i)%31])
        toffoli4(nfsr1[(1+i)%31], nfsr1[(24+i)%31],nfsr2[(38+i)%90],nfsr2[(63+i)%90], nfsr1[(0+i)%31])
        
        qc.cx(nfsr1[(0+i)%31], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(24+i)%90], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(49+i)%90], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(79+i)%90], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(84+i)%90], nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(3+i)%90], nfsr2[(59+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(10+i)%90], nfsr2[(12+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(15+i)%90], nfsr2[(16+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(25+i)%90], nfsr2[(53+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(35+i)%90], nfsr2[(42+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(55+i)%90], nfsr2[(58+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(60+i)%90], nfsr2[(74+i)%90],nfsr2[(0+i)%90])
        
        toffoli3(nfsr2[(20+i)%90], nfsr2[(22+i)%90],nfsr2[(23+i)%90],nfsr2[(0+i)%90])
        toffoli3(nfsr2[(62+i)%90], nfsr2[(68+i)%90],nfsr2[(78+i)%90],nfsr2[(0+i)%90])
        
        toffoli4(nfsr2[(77+i)%90], nfsr2[(80+i)%90],nfsr2[(81+i)%90],nfsr2[(83+i)%90],nfsr2[(0+i)%90])
        
        
        qc.cx(nfsr1[(2+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(5+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(6+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(15+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(17+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(18+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(20+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(25+i)%31],nfsr1[(0+i)%31])
        
        qc.ccx(nfsr1[(14+i)%31], nfsr1[(19+i)%31],anc[0])
        qc.ccx(nfsr1[(17+i)%31], nfsr1[(21+i)%31],anc[0])
        qc.cx(anc[0],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(17+i)%31], nfsr1[(21+i)%31],anc[0])
        qc.ccx(nfsr1[(14+i)%31], nfsr1[(19+i)%31],anc[0])
        
        qc.cx(nfsr1[(21+i)%31],anc[1])
        qc.x(anc[1])
        qc.ccx(nfsr1[(20+i)%31], nfsr1[(22+i)%31],anc[1])
        qc.cx(anc[1],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(20+i)%31], nfsr1[(22+i)%31],anc[1])
        qc.x(anc[1])
        qc.cx(nfsr1[(21+i)%31],anc[1])
        
        qc.cx(nfsr1[(4+i)%31],anc[3])
        qc.cx(nfsr1[(19+i)%31],anc[3])
        qc.cx(anc[3],anc[2])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(22+i)%31],anc[2])
        qc.cx(anc[2],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(22+i)%31],anc[2])
        qc.cx(anc[3],anc[2])
        
        qc.cx(nfsr1[(7+i)%31],anc[4])
        qc.cx(nfsr1[(22+i)%31],anc[4])
        qc.ccx(anc[3],anc[4],anc[5])
        qc.x(anc[5])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(21+i)%31],anc[5])
        qc.cx(anc[5],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(21+i)%31],anc[5])
        qc.x(anc[5])
        qc.ccx(anc[3],anc[4],anc[5])
        qc.cx(nfsr1[(22+i)%31],anc[4])
        qc.cx(nfsr1[(7+i)%31],anc[4])
        qc.cx(nfsr1[(19+i)%31],anc[3])
        qc.cx(nfsr1[(4+i)%31],anc[3])
        
        
        qc.cx(nfsr1[(18+i)%31], anc[6])
        qc.cx(nfsr1[(20+i)%31], anc[6])
        qc.ccx(nfsr1[(8+i)%31],anc[6],anc[7])
        qc.cx(anc[7],nfsr1[(0+i)%31])

        
        qc.cx(nfsr1[(7+i)%31], anc[8])
        qc.cx(nfsr1[(22+i)%31], anc[8])
        qc.ccx(nfsr1[(21+i)%31],anc[8], anc[9])
        qc.cx(nfsr1[(22+i)%31], anc[9])
        qc.ccx(anc[9],anc[7],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(22+i)%31], anc[9])
        qc.ccx(nfsr1[(21+i)%31],anc[8], anc[9])
        qc.cx(nfsr1[(22+i)%31], anc[8])
        qc.cx(nfsr1[(7+i)%31], anc[8])
        qc.ccx(nfsr1[(8+i)%31],anc[6],anc[7])
        qc.cx(nfsr1[(20+i)%31], anc[6])
        qc.cx(nfsr1[(18+i)%31], anc[6])
        
        
        
def phase3():
    for i in range(90):
        qc.cx(key[i],nfsr2[i])
        
    for i in range(30):
        qc.cx(key[i+90],nfsr1[i])
        
    qc.x(nfsr1[30])
        
        
def phase4():
    for i in range(128):
        qc.cx(nfsr2[(7+i)%90],y[0])
        qc.cx(nfsr2[(11+i)%90],y[0])
        qc.cx(nfsr2[(30+i)%90],y[0])
        qc.cx(nfsr2[(40+i)%90],y[0])
        qc.cx(nfsr2[(45+i)%90],y[0])
        qc.cx(nfsr2[(54+i)%90],y[0])
        qc.cx(nfsr2[(71+i)%90],y[0])
        qc.cx(nfsr2[(5+i)%90],y[0])
        
        qc.ccx(nfsr2[(4+i)%90], nfsr2[(21+i)%90],y[0])
        qc.ccx(nfsr2[(9+i)%90], nfsr2[(52+i)%90],y[0])
        qc.ccx(nfsr2[(18+i)%90], nfsr2[(37+i)%90],y[0])
        qc.ccx(nfsr2[(44+i)%90], nfsr2[(76+i)%90],y[0])
        qc.ccx(nfsr2[(8+i)%90], nfsr2[(82+i)%90],y[0])
        
        toffoli3(nfsr2[(34+i)%90], nfsr2[(67+i)%90],nfsr2[(73+i)%90],y[0])
        toffoli4(nfsr2[(2+i)%90], nfsr2[(28+i)%90],nfsr2[(41+i)%90],nfsr2[(65+i)%90],y[0])
        
        toffoli5(nfsr2[(13+i)%90], nfsr2[(29+i)%90],nfsr2[(50+i)%90],nfsr2[(64+i)%90],nfsr2[(75+i)%90],y[0])
        toffoli6(nfsr2[(6+i)%90], nfsr2[(14+i)%90],nfsr2[(26+i)%90],nfsr2[(32+i)%90],nfsr2[(47+i)%90],nfsr2[(61+i)%90],y[0])
        toffoli7(nfsr2[(1+i)%90], nfsr2[(19+i)%90],nfsr2[(27+i)%90],nfsr2[(43+i)%90],nfsr2[(57+i)%90],nfsr2[(66+i)%90],nfsr2[(78+i)%90],y[0])
        
        qc.cx(nfsr1[(23+i)%31],y[0])
        qc.ccx(nfsr1[(3+i)%31], nfsr1[(16+i)%31],y[0])
        toffoli3(nfsr1[(9+i)%31], nfsr1[(13+i)%31],nfsr1[(48+i)%31],y[0])
        toffoli4(nfsr1[(1+i)%31], nfsr1[(24+i)%31],nfsr2[(38+i)%90],nfsr2[(63+i)%90],y[0])
        
        
        
        qc.cx(nfsr1[(0+i)%31], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(24+i)%90], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(49+i)%90], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(79+i)%90], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(84+i)%90], nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(3+i)%90], nfsr2[(59+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(10+i)%90], nfsr2[(12+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(15+i)%90], nfsr2[(16+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(25+i)%90], nfsr2[(53+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(35+i)%90], nfsr2[(42+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(55+i)%90], nfsr2[(58+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(60+i)%90], nfsr2[(74+i)%90],nfsr2[(0+i)%90])
        
        toffoli3(nfsr2[(20+i)%90], nfsr2[(22+i)%90],nfsr2[(23+i)%90],nfsr2[(0+i)%90])
        toffoli3(nfsr2[(62+i)%90], nfsr2[(68+i)%90],nfsr2[(78+i)%90],nfsr2[(0+i)%90])
        
        toffoli4(nfsr2[(77+i)%90], nfsr2[(80+i)%90],nfsr2[(81+i)%90],nfsr2[(83+i)%90],nfsr2[(0+i)%90])
        
        
        qc.cx(nfsr1[(2+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(5+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(6+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(15+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(17+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(18+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(20+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(25+i)%31],nfsr1[(0+i)%31])
        
        qc.ccx(nfsr1[(14+i)%31], nfsr1[(19+i)%31],anc[0])
        qc.ccx(nfsr1[(17+i)%31], nfsr1[(21+i)%31],anc[0])
        qc.cx(anc[0],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(17+i)%31], nfsr1[(21+i)%31],anc[0])
        qc.ccx(nfsr1[(14+i)%31], nfsr1[(19+i)%31],anc[0])
        
        qc.cx(nfsr1[(21+i)%31],anc[1])
        qc.x(anc[1])
        qc.ccx(nfsr1[(20+i)%31], nfsr1[(22+i)%31],anc[1])
        qc.cx(anc[1],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(20+i)%31], nfsr1[(22+i)%31],anc[1])
        qc.x(anc[1])
        qc.cx(nfsr1[(21+i)%31],anc[1])
        
        qc.cx(nfsr1[(4+i)%31],anc[3])
        qc.cx(nfsr1[(19+i)%31],anc[3])
        qc.cx(anc[3],anc[2])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(22+i)%31],anc[2])
        qc.cx(anc[2],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(22+i)%31],anc[2])
        qc.cx(anc[3],anc[2])
        
        qc.cx(nfsr1[(7+i)%31],anc[4])
        qc.cx(nfsr1[(22+i)%31],anc[4])
        qc.ccx(anc[3],anc[4],anc[5])
        qc.x(anc[5])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(21+i)%31],anc[5])
        qc.cx(anc[5],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(21+i)%31],anc[5])
        qc.x(anc[5])
        qc.ccx(anc[3],anc[4],anc[5])
        qc.cx(nfsr1[(22+i)%31],anc[4])
        qc.cx(nfsr1[(7+i)%31],anc[4])
        qc.cx(nfsr1[(19+i)%31],anc[3])
        qc.cx(nfsr1[(4+i)%31],anc[3])
        
        
        qc.cx(nfsr1[(18+i)%31], anc[6])
        qc.cx(nfsr1[(20+i)%31], anc[6])
        qc.ccx(nfsr1[(8+i)%31],anc[6],anc[7])
        qc.cx(anc[7],nfsr1[(0+i)%31])

        
        qc.cx(nfsr1[(7+i)%31], anc[8])
        qc.cx(nfsr1[(22+i)%31], anc[8])
        qc.ccx(nfsr1[(21+i)%31],anc[8], anc[9])
        qc.cx(nfsr1[(22+i)%31], anc[9])
        qc.ccx(anc[9],anc[7],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(22+i)%31], anc[9])
        qc.ccx(nfsr1[(21+i)%31],anc[8], anc[9])
        qc.cx(nfsr1[(22+i)%31], anc[8])
        qc.cx(nfsr1[(7+i)%31], anc[8])
        qc.ccx(nfsr1[(8+i)%31],anc[6],anc[7])
        qc.cx(nfsr1[(20+i)%31], anc[6])
        qc.cx(nfsr1[(18+i)%31], anc[6])
        

def keystream():
    for i in range(130):
        qc.cx(nfsr2[(7+i)%90],y[i+1])
        qc.cx(nfsr2[(11+i)%90],y[i+1])
        qc.cx(nfsr2[(30+i)%90],y[i+1])
        qc.cx(nfsr2[(40+i)%90],y[i+1])
        qc.cx(nfsr2[(45+i)%90],y[i+1])
        qc.cx(nfsr2[(54+i)%90],y[i+1])
        qc.cx(nfsr2[(71+i)%90],y[i+1])
        qc.cx(nfsr2[(5+i)%90],y[i+1])
        
        qc.ccx(nfsr2[(4+i)%90], nfsr2[(21+i)%90],y[i+1])
        qc.ccx(nfsr2[(9+i)%90], nfsr2[(52+i)%90],y[i+1])
        qc.ccx(nfsr2[(18+i)%90], nfsr2[(37+i)%90],y[i+1])
        qc.ccx(nfsr2[(44+i)%90], nfsr2[(76+i)%90],y[i+1])
        qc.ccx(nfsr2[(8+i)%90], nfsr2[(82+i)%90],y[i+1])
        
        toffoli3(nfsr2[(34+i)%90], nfsr2[(67+i)%90],nfsr2[(73+i)%90],y[i+1])
        toffoli4(nfsr2[(2+i)%90], nfsr2[(28+i)%90],nfsr2[(41+i)%90],nfsr2[(65+i)%90],y[i+1])
        
        toffoli5(nfsr2[(13+i)%90], nfsr2[(29+i)%90],nfsr2[(50+i)%90],nfsr2[(64+i)%90],nfsr2[(75+i)%90],y[i+1])
        toffoli6(nfsr2[(6+i)%90], nfsr2[(14+i)%90],nfsr2[(26+i)%90],nfsr2[(32+i)%90],nfsr2[(47+i)%90],nfsr2[(61+i)%90],y[i+1])
        toffoli7(nfsr2[(1+i)%90], nfsr2[(19+i)%90],nfsr2[(27+i)%90],nfsr2[(43+i)%90],nfsr2[(57+i)%90],nfsr2[(66+i)%90],nfsr2[(78+i)%90],y[i+1])
        
        qc.cx(nfsr1[(23+i)%31],y[i+1])
        qc.ccx(nfsr1[(3+i)%31], nfsr1[(16+i)%31],y[i+1])
        toffoli3(nfsr1[(9+i)%31], nfsr1[(13+i)%31],nfsr1[(48+i)%31],y[i+1])
        toffoli4(nfsr1[(1+i)%31], nfsr1[(24+i)%31],nfsr2[(38+i)%90],nfsr2[(63+i)%90],y[i+1])
        
        
        qc.cx(nfsr1[(0+i)%31], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(24+i)%90], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(49+i)%90], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(79+i)%90], nfsr2[(0+i)%90])
        qc.cx(nfsr2[(84+i)%90], nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(3+i)%90], nfsr2[(59+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(10+i)%90], nfsr2[(12+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(15+i)%90], nfsr2[(16+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(25+i)%90], nfsr2[(53+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(35+i)%90], nfsr2[(42+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(55+i)%90], nfsr2[(58+i)%90],nfsr2[(0+i)%90])
        qc.ccx(nfsr2[(60+i)%90], nfsr2[(74+i)%90],nfsr2[(0+i)%90])
        
        toffoli3(nfsr2[(20+i)%90], nfsr2[(22+i)%90],nfsr2[(23+i)%90],nfsr2[(0+i)%90])
        toffoli3(nfsr2[(62+i)%90], nfsr2[(68+i)%90],nfsr2[(78+i)%90],nfsr2[(0+i)%90])
        
        toffoli4(nfsr2[(77+i)%90], nfsr2[(80+i)%90],nfsr2[(81+i)%90],nfsr2[(83+i)%90],nfsr2[(0+i)%90])
        
      
        qc.cx(nfsr1[(2+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(5+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(6+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(15+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(17+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(18+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(20+i)%31],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(25+i)%31],nfsr1[(0+i)%31])
        
        qc.ccx(nfsr1[(14+i)%31], nfsr1[(19+i)%31],anc[0])
        qc.ccx(nfsr1[(17+i)%31], nfsr1[(21+i)%31],anc[0])
        qc.cx(anc[0],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(17+i)%31], nfsr1[(21+i)%31],anc[0])
        qc.ccx(nfsr1[(14+i)%31], nfsr1[(19+i)%31],anc[0])
        
        qc.cx(nfsr1[(21+i)%31],anc[1])
        qc.x(anc[1])
        qc.ccx(nfsr1[(20+i)%31], nfsr1[(22+i)%31],anc[1])
        qc.cx(anc[1],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(20+i)%31], nfsr1[(22+i)%31],anc[1])
        qc.x(anc[1])
        qc.cx(nfsr1[(21+i)%31],anc[1])
        
        qc.cx(nfsr1[(4+i)%31],anc[3])
        qc.cx(nfsr1[(19+i)%31],anc[3])
        qc.cx(anc[3],anc[2])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(22+i)%31],anc[2])
        qc.cx(anc[2],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(22+i)%31],anc[2])
        qc.cx(anc[3],anc[2])
        
        qc.cx(nfsr1[(7+i)%31],anc[4])
        qc.cx(nfsr1[(22+i)%31],anc[4])
        qc.ccx(anc[3],anc[4],anc[5])
        qc.x(anc[5])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(21+i)%31],anc[5])
        qc.cx(anc[5],nfsr1[(0+i)%31])
        qc.ccx(nfsr1[(12+i)%31], nfsr1[(21+i)%31],anc[5])
        qc.x(anc[5])
        qc.ccx(anc[3],anc[4],anc[5])
        qc.cx(nfsr1[(22+i)%31],anc[4])
        qc.cx(nfsr1[(7+i)%31],anc[4])
        qc.cx(nfsr1[(19+i)%31],anc[3])
        qc.cx(nfsr1[(4+i)%31],anc[3])
        
        
        qc.cx(nfsr1[(18+i)%31], anc[6])
        qc.cx(nfsr1[(20+i)%31], anc[6])
        qc.ccx(nfsr1[(8+i)%31],anc[6],anc[7])
        qc.cx(anc[7],nfsr1[(0+i)%31])

        
        qc.cx(nfsr1[(7+i)%31], anc[8])
        qc.cx(nfsr1[(22+i)%31], anc[8])
        qc.ccx(nfsr1[(21+i)%31],anc[8], anc[9])
        qc.cx(nfsr1[(22+i)%31], anc[9])
        qc.ccx(anc[9],anc[7],nfsr1[(0+i)%31])
        qc.cx(nfsr1[(22+i)%31], anc[9])
        qc.ccx(nfsr1[(21+i)%31],anc[8], anc[9])
        qc.cx(nfsr1[(22+i)%31], anc[8])
        qc.cx(nfsr1[(7+i)%31], anc[8])
        qc.ccx(nfsr1[(8+i)%31],anc[6],anc[7])
        qc.cx(nfsr1[(20+i)%31], anc[6])
        qc.cx(nfsr1[(18+i)%31], anc[6])
        
from qiskit import *
# %matplotlib inline
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.visualization import plot_histogram
 
nfsr1 = QuantumRegister(31)
nfsr2 = QuantumRegister(90)
key = QuantumRegister(120)
y = QuantumRegister(131)
anc = QuantumRegister(10)
qc = QuantumCircuit(nfsr1,nfsr2,key,anc,y)

iv = [1]*64


phase1()
phase2()
phase3()
phase4()
keystream()

print (qc.count_ops())
print (qc.width())
print (qc.depth())
